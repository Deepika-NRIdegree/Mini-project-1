# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika-NRIdegree/Mini-project-1/blob/main/introduction_of_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
    age.append(random.randint(0,100))
    height.append(random.randint(0,100))
    weight.append(random.randint(0,100))
    speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'weight':weight,'Speed':speed}
idata
# Out:
# {'Age': [86,
#   82,
#   99,
#   5,
#   62,
#   94,
#   58,
#   20,
#   25,
#   33,
#   50,
#   5,
#   64,
#   82,
#   2,
#   20,
#   22,
#   41,
#   74,
#   18,
#   55,
#   29,
#   63,
#   61,
#   65,
#   9,
#   48,
#   63,
#   97,
#   5,
#   38,
#   25,
#   84,
#   48,
#   23,
#   58,
#   89,
#   71,
#   84,
#   54,
#   97,
#   35,
#   17,
#   73,
#   0,
#   97,
#   16,
#   82,
#   46,
#   96,
#   6,
#   27,
#   89,
#   69,
#   1,
#   3,
#   31,
#   61,
#   33,
#   94,
#   39,
#   44,
#   75,
#   55,
#   65,
#   2,
#   34,
#   8,
#   88,
#   39,
#   40,
#   93,
#   32,
#   98,
#   67,
#   36,
#   52,
#   32,
#   9,
#   45,
#   41,
#   9,
#   35,
#   30,
#   0,
#   35,
#   24,
#   18,
#   29,
#   90,
#   26,
#   30,
#   70,
#   73,
#   66,
#   74,
#   72,
#   58,
#   45,
#   29],
#  'Height': [83,
#   58,
#   28,
#   4,
#   63,
#   65,
#   65,
#   86,
#   86,
#   9,
#   20,
#   40,
#   63,
#   7,
#   5,
#   26,
#   91,
#   53,
#   45,
#   49,
#   79,
#   6,
#   37,
#   20,
#   82,
#   86,
#   36,
#   17,
#   32,
#   3,
#   81,
#   79,
#   41,
#   93,
#   91,
#   64,
#   84,
#   73,
#   39,
#   22,
#   40,
#   43,
#   56,
#   66,
#   75,
#   46,
#   91,
#   3,
#   50,
#   69,
#   58,
#   42,
#   57,
#   8,
#   3,
#   68,
#   11,
#   66,
#   97,
#   40,
#   62,
#   13,
#   66,
#   26,
#   45,
#   94,
#   82,
#   15,
#   61,
#   25,
#   95,
#   47,
#   36,
#   59,
#   13,
#   78,
#   82,
#   26,
#   93,
#   92,
#   51,
#   63,
#   8,
#   61,
#   22,
#   90,
#   51,
#   99,
#   16,
#   42,
#   69,
#   94,
#   23,
#   34,
#   86,
#   98,
#   12,
#   18,
#   38,
#   38],
#  'weight': [26,
#   5,
#   50,
#   70,
#   75,
#   7,
#   16,
#   32,
#   63,
#   73,
#   99,
#   83,
#   21,
#   100,
#   37,
#   38,
#   63,
#   36,
#   25,
#   76,
#   15,
#   9,
#   73,
#   91,
#   82,
#   1,
#   76,
#   83,
#   35,
#   70,
#   52,
#   6,
#   98,
#   84,
#   9,
#   18,
#   80,
#   22,
#   67,
#   52,
#   30,
#   90,
#   82,
#   16,
#   22,
#   74,
#   94,
#   61,
#   54,
#   74,
#   16,
#   71,
#   55,
#   34,
#   37,
#   82,
#   63,
#   69,
#   29,
#   32,
#   70,
#   89,
#   15,
#   55,
#   73,
#   59,
#   56,
#   98,
#   72,
#   77,
#   72,
#   89,
#   73,
#   40,
#   6,
#   53,
#   96,
#   42,
#   83,
#   74,
#   44,
#   82,
#   24,
#   62,
#   27,
#   80,
#   63,
#   34,
#   45,
#   54,
#   9,
#   82,
#   71,
#   9,
#   75,
#   31,
#   92,
#   79,
#   98,
#   52],
#  'Speed': [99,
#   84,
#   28,
#   4,
#   30,
#   93,
#   90,
#   91,
#   0,
#   20,
#   38,
#   17,
#   69,
#   99,
#   72,
#   37,
#   3,
#   61,
#   66,
#   97,
#   30,
#   77,
#   26,
#   16,
#   40,
#   24,
#   31,
#   23,
#   13,
#   0,
#   0,
#   48,
#   63,
#   50,
#   8,
#   0,
#   33,
#   25,
#   43,
#   64,
#   53,
#   21,
#   43,
#   35,
#   77,
#   21,
#   55,
#   60,
#   11,
#   60,
#   97,
#   92,
#   81,
#   60,
#   80,
#   32,
#   94,
#   95,
#   82,
#   64,
#   99,
#   30,
#   9,
#   82,
#   64,
#   49,
#   54,
#   67,
#   41,
#   38,
#   58,
#   94,
#   68,
#   30,
#   91,
#   45,
#   39,
#   60,
#   57,
#   87,
#   92,
#   89,
#   75,
#   23,
#   11,
#   47,
#   24,
#   4,
#   79,
#   54,
#   73,
#   51,
#   24,
#   44,
#   55,
#   83,
#   51,
#   15,
#   91,
#   16]}

# %%
 df1 = pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               Age      Height      weight      Speed
# count  100.000000  100.000000  100.000000  100.00000
# mean    47.910000   51.230000   55.080000   50.88000
# std     29.035713   28.881805   28.016835   29.39844
# min      0.000000    3.000000    1.000000    0.00000
# 25%     25.750000   26.000000   31.750000   25.75000
# 50%     45.000000   51.000000   61.500000   51.00000
# 75%     71.250000   78.250000   76.250000   77.00000
# max     99.000000   99.000000  100.000000   99.00000

# %%
df1[['Age', 'Height']]
# Out:
#     Age  Height
# 0    86      83
# 1    82      58
# 2    99      28
# 3     5       4
# 4    62      63
# ..  ...     ...
# 95   74      98
# 96   72      12
# 97   58      18
# 98   45      38
# 99   29      38
#
# [100 rows x 2 columns]

# %%
df1[0:2]
# Out:
#    Age  Height  weight  Speed
# 0   86      83      26     99
# 1   82      58       5     84

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   86      83
# 3    5       4

# %%
df1.sort_index()
# Out:
#     Age  Height  weight  Speed
# 0    86      83      26     99
# 1    82      58       5     84
# 2    99      28      50     28
# 3     5       4      70      4
# 4    62      63      75     30
# ..  ...     ...     ...    ...
# 95   74      98      31     83
# 96   72      12      92     51
# 97   58      18      79     15
# 98   45      38      98     91
# 99   29      38      52     16
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe ()
# Out:
#              Age     Height     weight      Speed
# count  50.000000  50.000000  50.000000  50.000000
# mean   48.660000  54.000000  54.160000  52.200000
# std    28.517528  27.856777  27.818919  29.447289
# min     0.000000   3.000000   6.000000   0.000000
# 25%    26.750000  36.000000  27.500000  30.000000
# 50%    47.000000  56.500000  59.500000  54.500000
# 75%    69.250000  81.750000  74.500000  76.500000
# max    99.000000  97.000000  99.000000  99.000000

# %%
#Filtet
filter1 = df1['Age']>50

# %%
df1[filter1]
# Out:
#     Age  Height  weight  Speed
# 0    86      83      26     99
# 1    82      58       5     84
# 2    99      28      50     28
# 4    62      63      75     30
# 5    94      65       7     93
# 6    58      65      16     90
# 12   64      63      21     69
# 13   82       7     100     99
# 18   74      45      25     66
# 20   55      79      15     30
# 22   63      37      73     26
# 23   61      20      91     16
# 24   65      82      82     40
# 27   63      17      83     23
# 28   97      32      35     13
# 32   84      41      98     63
# 35   58      64      18      0
# 36   89      84      80     33
# 37   71      73      22     25
# 38   84      39      67     43
# 39   54      22      52     64
# 40   97      40      30     53
# 43   73      66      16     35
# 45   97      46      74     21
# 47   82       3      61     60
# 49   96      69      74     60
# 52   89      57      55     81
# 53   69       8      34     60
# 57   61      66      69     95
# 59   94      40      32     64
# 62   75      66      15      9
# 63   55      26      55     82
# 64   65      45      73     64
# 68   88      61      72     41
# 71   93      47      89     94
# 73   98      59      40     30
# 74   67      13       6     91
# 76   52      82      96     39
# 89   90      42      54     54
# 92   70      23      71     24
# 93   73      34       9     44
# 94   66      86      75     55
# 95   74      98      31     83
# 96   72      12      92     51
# 97   58      18      79     15

# %%
df1.loc[filter1]
# Out:
#     Age  Height  weight  Speed
# 0    86      83      26     99
# 1    82      58       5     84
# 2    99      28      50     28
# 4    62      63      75     30
# 5    94      65       7     93
# 6    58      65      16     90
# 12   64      63      21     69
# 13   82       7     100     99
# 18   74      45      25     66
# 20   55      79      15     30
# 22   63      37      73     26
# 23   61      20      91     16
# 24   65      82      82     40
# 27   63      17      83     23
# 28   97      32      35     13
# 32   84      41      98     63
# 35   58      64      18      0
# 36   89      84      80     33
# 37   71      73      22     25
# 38   84      39      67     43
# 39   54      22      52     64
# 40   97      40      30     53
# 43   73      66      16     35
# 45   97      46      74     21
# 47   82       3      61     60
# 49   96      69      74     60
# 52   89      57      55     81
# 53   69       8      34     60
# 57   61      66      69     95
# 59   94      40      32     64
# 62   75      66      15      9
# 63   55      26      55     82
# 64   65      45      73     64
# 68   88      61      72     41
# 71   93      47      89     94
# 73   98      59      40     30
# 74   67      13       6     91
# 76   52      82      96     39
# 89   90      42      54     54
# 92   70      23      71     24
# 93   73      34       9     44
# 94   66      86      75     55
# 95   74      98      31     83
# 96   72      12      92     51
# 97   58      18      79     15

# %%
filter2 = df1['Age']>50

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  weight  Speed
# 0    86      83      26     99
# 1    82      58       5     84
# 2    99      28      50     28
# 4    62      63      75     30
# 5    94      65       7     93
# 6    58      65      16     90
# 12   64      63      21     69
# 13   82       7     100     99
# 18   74      45      25     66
# 20   55      79      15     30
# 22   63      37      73     26
# 23   61      20      91     16
# 24   65      82      82     40
# 27   63      17      83     23
# 28   97      32      35     13
# 32   84      41      98     63
# 35   58      64      18      0
# 36   89      84      80     33
# 37   71      73      22     25
# 38   84      39      67     43
# 39   54      22      52     64
# 40   97      40      30     53
# 43   73      66      16     35
# 45   97      46      74     21
# 47   82       3      61     60
# 49   96      69      74     60
# 52   89      57      55     81
# 53   69       8      34     60
# 57   61      66      69     95
# 59   94      40      32     64
# 62   75      66      15      9
# 63   55      26      55     82
# 64   65      45      73     64
# 68   88      61      72     41
# 71   93      47      89     94
# 73   98      59      40     30
# 74   67      13       6     91
# 76   52      82      96     39
# 89   90      42      54     54
# 92   70      23      71     24
# 93   73      34       9     44
# 94   66      86      75     55
# 95   74      98      31     83
# 96   72      12      92     51
# 97   58      18      79     15
