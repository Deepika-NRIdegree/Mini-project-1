# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika-NRIdegree/Mini-project-1/blob/main/Random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range (1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5
}

# %%
import pandas as pd

# %%
df
# Out:
# {'grade': [1,
#   9,
#   100,
#   9,
#   18,
#   58,
#   49,
#   80,
#   17,
#   24,
#   21,
#   16,
#   11,
#   28,
#   64,
#   75,
#   23,
#   76,
#   63,
#   84,
#   28,
#   25,
#   55,
#   59,
#   11,
#   87,
#   31,
#   76,
#   47,
#   52,
#   47,
#   10,
#   19,
#   19,
#   42,
#   72,
#   33,
#   11,
#   13,
#   20,
#   97,
#   94,
#   11,
#   49,
#   32,
#   70,
#   64,
#   90,
#   0,
#   42,
#   70,
#   25,
#   5,
#   79,
#   68,
#   99,
#   41,
#   69,
#   6,
#   6,
#   43,
#   51,
#   91,
#   95,
#   72,
#   55,
#   89,
#   78,
#   10,
#   26,
#   1,
#   90,
#   93,
#   59,
#   41,
#   46,
#   4,
#   51,
#   82,
#   31,
#   27,
#   62,
#   51,
#   55,
#   97,
#   20,
#   49,
#   93,
#   69,
#   80,
#   82,
#   3,
#   18,
#   9,
#   45,
#   79,
#   75,
#   59,
#   34,
#   96,
#   7,
#   79,
#   17,
#   47,
#   29,
#   53,
#   98,
#   52,
#   1,
#   66,
#   95,
#   63,
#   46,
#   64,
#   79,
#   37,
#   42,
#   6,
#   77,
#   89,
#   92,
#   52,
#   6,
#   99,
#   62,
# ...

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df
# Out:
# {'grade': [49,
#   3,
#   70,
#   37,
#   52,
#   19,
#   30,
#   66,
#   82,
#   45,
#   57,
#   62,
#   51,
#   51,
#   86,
#   66,
#   82,
#   41,
#   41,
#   5,
#   39,
#   5,
#   38,
#   55,
#   62,
#   31,
#   37,
#   72,
#   55,
#   99,
#   81,
#   7,
#   67,
#   23,
#   30,
#   58,
#   95,
#   32,
#   51,
#   41,
#   48,
#   15,
#   45,
#   21,
#   63,
#   67,
#   53,
#   35,
#   23,
#   23,
#   33,
#   88,
#   98,
#   68,
#   26,
#   93,
#   89,
#   71,
#   70,
#   64,
#   86,
#   34,
#   77,
#   39,
#   9,
#   98,
#   16,
#   86,
#   41,
#   29,
#   33,
#   100,
#   21,
#   93,
#   35,
#   6,
#   95,
#   1,
#   74,
#   0,
#   36,
#   39,
#   34,
#   6,
#   25,
#   70,
#   15,
#   76,
#   24,
#   56,
#   20,
#   52,
#   26,
#   65,
#   99,
#   85,
#   37,
#   2,
#   10,
#   6,
#   49,
#   70,
#   7,
#   77,
#   36,
#   71,
#   60,
#   96,
#   77,
#   39,
#   1,
#   44,
#   8,
#   38,
#   99,
#   41,
#   60,
#   27,
#   58,
#   59,
#   0,
#   48,
#   65,
#   62,
#   7,
# ...

# %%
df1.describe()
# Out:
#             grade       weight      friends      cousins   projects
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.0000
# mean     49.81800    60.076000    14.854000     7.516000    50.1290
# std      29.03515     6.062093     3.146838     1.706064    17.6722
# min       0.00000    50.000000    10.000000     5.000000    20.0000
# 25%      24.75000    55.000000    12.000000     6.000000    35.0000
# 50%      49.50000    60.000000    15.000000     8.000000    49.0000
# 75%      76.00000    65.000000    17.000000     9.000000    65.0000
# max     100.00000    70.000000    20.000000    10.000000    80.0000

# %%
df1['grade']. count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0        1
# 1        9
# 2      100
# 3        9
# 4       18
#       ...
# 995     30
# 996     71
# 997     82
# 998     34
# 999     11
# Name: grade, Length: 1000, dtype: int64>

# %%
friend18 = df1['friends'] > 18

# %%
df1[friend18]
# Out:
#      grade  weight  friends  cousins  projects
# 1        9      67       19        8        20
# 2      100      53       20        5        68
# 3        9      56       19        7        46
# 8       17      56       20        9        51
# 13      28      64       19       10        48
# ..     ...     ...      ...      ...       ...
# 977     26      66       19        6        57
# 986     84      60       19        5        70
# 988     63      59       19        6        20
# 989     79      70       20       10        37
# 997     82      70       19        5        43
#
# [167 rows x 5 columns]

# %%
grade98 = df1['grade'] > 98

# %%
 df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 2      100      53       20        5        68
# 55      99      61       11        6        34
# 123     99      56       19       10        29
# 181    100      65       15        8        62
# 229    100      67       19        7        39
# 267     99      70       14        8        76
# 277     99      64       18       10        56
# 295     99      65       15       10        54
# 355     99      60       18       10        25
# 379    100      66       15        8        30
# 380     99      56       15        6        26
# 567     99      65       12        7        43
# 588    100      58       14        8        52
# 682     99      59       20        9        24
# 702     99      50       17        9        77
# 841    100      52       18        7        57
# 897     99      63       11        9        57
# 982    100      62       17        5        77

# %%
df1[friend18 & grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 2      100      53       20        5        68
# 123     99      56       19       10        29
# 229    100      67       19        7        39
# 682     99      59       20        9        24

# %%
df1[freind18 & grade98].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 99     56      19       10       29          1
#        59      20       9        24          1
# 100    53      20       5        68          1
#        67      19       7        39          1
# Name: count, dtype: int64

# %%
df1[friend18 & grade98]['friends']. value_counts()
# Out:
# friends
# 20    2
# 19    2
# Name: count, dtype: int64

# %%
pip install matlplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement matlplotlib (from versions: none)
# ERROR: No matching distribution found for matlplotlib

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade98].plot()
# Out:
# <Axes: >

# %%
df1[friend18 & grade98].plot(x = 'grade',y = 'projects', kind='area')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend18 & grade98].plot(x = 'grade',y = 'projects', kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friend18 & grade98].plot(x = 'grade',y = 'projects', kind='pie',title='sample graph')
# Out:
# <Axes: title={'center': 'sample graph'}, ylabel='projects'>

# %%
fdf = df1[friend18 & grade98]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 2      100      53       20        5        68
# 123     99      56       19       10        29
# 229    100      67       19        7        39
# 682     99      59       20        9        24

# %%
df1[friend18 & grade98].plot(x = 'grade',y = 'weight', kind='bar', title= 'sample graph')
plt.xlabe('X Axis')
plt.ylable('Y Axis')
plt.lagend('Taste Data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-172-ab0ce2822867> in <cell line: 0>()
#       1 df1[friend18 & grade98].plot(x = 'grade',y = 'weight', kind='bar', title= 'sample graph')
# ----> 2 plt.xlabe('X Axis')
#       3 plt.ylable('Y Axis')
#       4 plt.lagend('Taste Data')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df1.to_csv('//python-apt.tar.xz.csv')
